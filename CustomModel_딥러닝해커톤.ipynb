# %%
#Import Library
import os
import shutil
import glob
import cv2
import numpy as np
import zipfile

# %%
#Drive Mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#GPU 
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
local_zip = '/content/drive/MyDrive/딥러닝 해커톤/Training.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
os.makedirs('/tmp/train')
zip_ref.extractall('/tmp/train')
zip_ref.close()

# %%
#데이터를 배열로 초기화
data = {}
data['0'] = []
data['1'] = []
data['2'] = []
data['3'] = []
data['4'] = []

# %%
#0 Data
src = '/content/drive/MyDrive/딥러닝 해커톤/Training/0'
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['0'].append(jpgImage)
print(len(data['0']))
# Out:
# 2231

# %%
#1 Data
src = '/tmp/train/1'
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['1'].append(jpgImage)
print(len(data['1']))
# Out:
# 1028

# %%
#2 Data
src = '/tmp/train/2'
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['2'].append(jpgImage)
print(len(data['2']))
# Out:
# 1029

# %%
#3 Data
src = '/tmp/train/3'
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['3'].append(jpgImage)
print(len(data['3']))
# Out:
# 1071

# %%
#4 Data
src = '/tmp/train/4'
for jpgImage in glob.iglob(os.path.join(src, '*jpg')):
    data['4'].append(jpgImage)
print(len(data['4']))
# Out:
# 1076

# %%
#Create File
os.mkdir('master_data_concrete')
os.mkdir('master_data_concrete/training')
os.mkdir('master_data_concrete/validation')
os.mkdir('master_data_concrete/test')

os.mkdir('master_data_concrete/training/00')
os.mkdir('master_data_concrete/training/01')
os.mkdir('master_data_concrete/training/02')
os.mkdir('master_data_concrete/training/03')
os.mkdir('master_data_concrete/training/04')

os.mkdir('master_data_concrete/validation/00')
os.mkdir('master_data_concrete/validation/01')
os.mkdir('master_data_concrete/validation/02')
os.mkdir('master_data_concrete/validation/03')
os.mkdir('master_data_concrete/validation/04')

os.mkdir('master_data_concrete/test/00')
os.mkdir('master_data_concrete/test/01')
os.mkdir('master_data_concrete/test/02')
os.mkdir('master_data_concrete/test/03')
os.mkdir('master_data_concrete/test/04')

# %%
#Data shuffle
from sklearn.model_selection import train_test_split
import sys

X = data['0'] #Data
Y = np.zeros((len(data['0']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.3)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))
# Out:
# X_train Data list = 1248    Y_train Label list = 1248
# X_valid Data list = 536    Y_valid Label list = 536
# X_test Data list = 447    Y_test Label list = 447

# %%
#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', '00')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', '00')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', '00')
        shutil.copy(image, dest)
# Out:
#   0%|          | 0/1248 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-b736787c3044> in <module>()
#       7 for image in tqdm(X_train):
#       8         dest = os.path.join(base_dest, 'training', '00')
# ----> 9         shutil.copy(image, dest)
#      10
#      11 #copy validation images of crack type
#
# /usr/lib/python3.7/shutil.py in copy(src, dst, follow_symlinks)
#     246     if os.path.isdir(dst):
#     247         dst = os.path.join(dst, os.path.basename(src))
# --> 248     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     249     copymode(src, dst, follow_symlinks=follow_symlinks)
#     250     return dst
#
# /usr/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
# --> 122                 copyfileobj(fsrc, fdst)
#     123     return dst
#     124
#
# /usr/lib/python3.7/shutil.py in copyfileobj(fsrc, fdst, length)
#      77     """copy data from file-like object fsrc to file-like object fdst"""
#      78     while 1:
# ---> 79         buf = fsrc.read(length)
#      80         if not buf:
#      81             break
#
# KeyboardInterrupt:

# %%
#Data shuffle
from sklearn.model_selection import train_test_split
import sys

X = data['1'] #Data
Y = np.zeros((len(data['1']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.3)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))
# Out:
# X_train Data list = 575    Y_train Label list = 575
# X_valid Data list = 247    Y_valid Label list = 247
# X_test Data list = 206    Y_test Label list = 206

# %%
#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', '01')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', '01')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', '01')
        shutil.copy(image, dest)
# Out:
#   0%|          | 0/575 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-3a10b82b699f> in <module>()
#       7 for image in tqdm(X_train):
#       8         dest = os.path.join(base_dest, 'training', '01')
# ----> 9         shutil.copy(image, dest)
#      10
#      11 #copy validation images of crack type
#
# /usr/lib/python3.7/shutil.py in copy(src, dst, follow_symlinks)
#     246     if os.path.isdir(dst):
#     247         dst = os.path.join(dst, os.path.basename(src))
# --> 248     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     249     copymode(src, dst, follow_symlinks=follow_symlinks)
#     250     return dst
#
# /usr/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     119     else:
#     120         with open(src, 'rb') as fsrc:
# --> 121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#     123     return dst
#
# FileNotFoundError: [Errno 2] No such file or directory: 'master_data_concrete/training/01'

# %%
#Data shuffle
from sklearn.model_selection import train_test_split
import sys

X = data['2'] #Data
Y = np.zeros((len(data['2']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.3)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))
# Out:
# X_train Data list = 576    Y_train Label list = 576
# X_valid Data list = 247    Y_valid Label list = 247
# X_test Data list = 206    Y_test Label list = 206

# %%
#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', '02')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', '02')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', '02')
        shutil.copy(image, dest)
# Out:
#   0%|          | 0/599 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-8ca3def65608> in <module>()
#       7 for image in tqdm(X_train):
#       8         dest = os.path.join(base_dest, 'training', '02')
# ----> 9         shutil.copy(image, dest)
#      10
#      11 #copy validation images of crack type
#
# /usr/lib/python3.7/shutil.py in copy(src, dst, follow_symlinks)
#     246     if os.path.isdir(dst):
#     247         dst = os.path.join(dst, os.path.basename(src))
# --> 248     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     249     copymode(src, dst, follow_symlinks=follow_symlinks)
#     250     return dst
#
# /usr/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     119     else:
#     120         with open(src, 'rb') as fsrc:
# --> 121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#     123     return dst
#
# FileNotFoundError: [Errno 2] No such file or directory: 'master_data_concrete/training/02'

# %%
#Data shuffle
from sklearn.model_selection import train_test_split
import sys

X = data['3'] #Data
Y = np.zeros((len(data['3']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.3)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))
# Out:
# X_train Data list = 599    Y_train Label list = 599
# X_valid Data list = 257    Y_valid Label list = 257
# X_test Data list = 215    Y_test Label list = 215

# %%
#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', '03')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', '03')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', '03')
        shutil.copy(image, dest)

# %%
#Data shuffle
from sklearn.model_selection import train_test_split
import sys

X = data['4'] #Data
Y = np.zeros((len(data['4']))) #Labels

#train : valid : test = 6 : 2 : 2
X_S, X_test, Y_S, Y_test = train_test_split(X,Y, test_size=0.2)
X_train, X_valid, Y_train, Y_valid = train_test_split(X_S,Y_S, test_size=0.3)
#assert len(X_train) == len(data['crack'])/10*8 , 'Data Numeric Error'

#Data Check
print('X_train Data list =',len(X_train), '   Y_train Label list =',len(Y_train))
print('X_valid Data list =',len(X_valid), '   Y_valid Label list =',len(Y_valid))
print('X_test Data list =',len(X_test), '   Y_test Label list =',len(Y_test))
# Out:
# X_train Data list = 602    Y_train Label list = 602
# X_valid Data list = 258    Y_valid Label list = 258
# X_test Data list = 216    Y_test Label list = 216

# %%
#image copy
from tqdm.auto import tqdm

base_dest = 'master_data_concrete'

#copy training  images of crack type
for image in tqdm(X_train):
        dest = os.path.join(base_dest, 'training', '04')
        shutil.copy(image, dest)

#copy validation images of crack type
for image in tqdm(X_valid):
        dest = os.path.join(base_dest, 'validation', '04')
        shutil.copy(image, dest)

#copy test images of crack type
for image in tqdm(X_test):
        dest = os.path.join(base_dest, 'test', '04')
        shutil.copy(image, dest)

# %%
base_dest = 'master_data_concrete'
dest = os.path.join(base_dest, 'training','00')
dest
# Out:
# 'master_data_concrete/training/00'

# %%
#Model Library
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,BatchNormalization
from keras.callbacks  import EarlyStopping, LambdaCallback
from keras.layers import Activation, Dropout,Input, Flatten, Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator

# %%
#Convolutional Layer
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3)))  #size 227 -> 150
model.add(BatchNormalization(axis=-1)) #Normalize Batch
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


#Output Layer
model.add(Flatten())  #3D를 1D로 벡터 변환
model.add(Dense(128))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.4))

model.add(Dense(64))
model.add(BatchNormalization(axis=-1))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(5)) 
model.add(BatchNormalization(axis=-1))
model.add(Activation('softmax'))  #or model.add(Activation('softmax')) // two output softmax == one output sigmoid

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 148, 148, 32)      896
#
#  batch_normalization_5 (Batc  (None, 148, 148, 32)     128
#  hNormalization)
#
#  activation_5 (Activation)   (None, 148, 148, 32)      0
#
#  max_pooling2d_2 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 72, 72, 64)        18496
#
#  batch_normalization_6 (Batc  (None, 72, 72, 64)       256
#  hNormalization)
#
#  activation_6 (Activation)   (None, 72, 72, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 82944)             0
#
#  dense_3 (Dense)             (None, 128)               10616960
#
#  batch_normalization_7 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_7 (Activation)   (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_8 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_8 (Activation)   (None, 64)                0
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
#  batch_normalization_9 (Batc  (None, 5)                20
#  hNormalization)
#
#  activation_9 (Activation)   (None, 5)                 0
#
# =================================================================
# Total params: 10,646,105
# Trainable params: 10,645,519
# Non-trainable params: 586
# _________________________________________________________________

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
#tf.keras.preprocessing.image_dataset_from_directory(
#    directory, labels='inferred', label_mode='int',
 #   class_names=None, color_mode='rgb', batch_size=32, image_size=(256,
 #   256), shuffle=True, seed=None, validation_split=None, subset=None,
 #   interpolation='bilinear', follow_links=False, smart_resize=False
#)

# %%
from keras.preprocessing.image import ImageDataGenerator

batch_size = 25
epochs = 100

#스케일 조정 및 과적합 방지
train_datagen = ImageDataGenerator (
        rescale=1./255, 
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

#validation,test에 사용할 확장구성
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

#train, validation, test 모든 이미지 크기 = 150*150
train_generator = train_datagen.flow_from_directory(
        '/content/master_data_concrete/training',  
        target_size=(150, 150), 
        batch_size=batch_size,
        shuffle=True,
        #color_mode='grayscale',
        class_mode='categorical')   #categorical_crossentropy loss를 사용하기 위한 categorical label

#검증 데이터
validation_generator = validation_datagen.flow_from_directory(
        '/content/master_data_concrete/validation',
        target_size=(150, 150),
        batch_size=batch_size,
        shuffle=True,
        #color_mode='grayscale',
        class_mode='categorical')

#테스트 데이터
test_generator = test_datagen.flow_from_directory(
       '/content/master_data_concrete/test',
       target_size=(150, 150),
       batch_size=batch_size,
       #color_mode='grayscale',
       class_mode='categorical')
# Out:
# Found 2915 images belonging to 5 classes.
# Found 1251 images belonging to 5 classes.
# Found 1045 images belonging to 5 classes.

# %%
4#만약 overfitting, underfitting 을 일으키면 EarlyStopping을 쓰기 위한 코드  or callback 함수 적용
#patience가 5면 validation score가 5회 이상 개선이 없을때 훈련을 멈춘다

from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.005)

# %%
#Model Learning
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) #rmsprop or adam or sgd , accuracy or f1-score  (positive와 negative의 데이터 값 차이가 높을 경우)
history = model.fit_generator(
        train_generator,
        epochs=epochs,
        validation_data=validation_generator)
        #,callbacks=[es])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 117/117 [==============================] - 97s 818ms/step - loss: 1.3253 - accuracy: 0.4666 - val_loss: 2.0128 - val_accuracy: 0.2278
# Epoch 2/100
# 117/117 [==============================] - 94s 805ms/step - loss: 1.0253 - accuracy: 0.6326 - val_loss: 1.7017 - val_accuracy: 0.3493
# Epoch 3/100
# 117/117 [==============================] - 93s 798ms/step - loss: 0.9129 - accuracy: 0.6803 - val_loss: 1.2946 - val_accuracy: 0.4476
# Epoch 4/100
# 117/117 [==============================] - 94s 807ms/step - loss: 0.7989 - accuracy: 0.7372 - val_loss: 1.2641 - val_accuracy: 0.4524
# Epoch 5/100
# 117/117 [==============================] - 93s 798ms/step - loss: 0.7240 - accuracy: 0.7763 - val_loss: 0.6319 - val_accuracy: 0.7922
# Epoch 6/100
# 117/117 [==============================] - 93s 794ms/step - loss: 0.6380 - accuracy: 0.8072 - val_loss: 0.8640 - val_accuracy: 0.6555
# Epoch 7/100
# 117/117 [==============================] - 93s 796ms/step - loss: 0.6277 - accuracy: 0.7986 - val_loss: 0.5504 - val_accuracy: 0.8361
# Epoch 8/100
# Epoch 85/100
# 117/117 [==============================] - 89s 762ms/step - loss: 0.0851 - accuracy: 0.9729 - val_loss: 0.4743 - val_accuracy: 0.8345
# Epoch 86/100
# 117/117 [==============================] - 88s 749ms/step - loss: 0.0855 - accuracy: 0.9712 - val_loss: 0.1094 - val_accuracy: 0.9664
# Epoch 87/100
# 117/117 [==============================] - 87s 747ms/step - loss: 0.0658 - accuracy: 0.9825 - val_loss: 0.2058 - val_accuracy: 0.9321
# Epoch 88/100
# 117/117 [==============================] - 87s 741ms/step - loss: 0.0707 - accuracy: 0.9794 - val_loss: 0.3256 - val_accuracy: 0.8785
# Epoch 89/100
# 117/117 [==============================] - 87s 748ms/step - loss: 0.0579 - accuracy: 0.9846 - val_loss: 0.2070 - val_accuracy: 0.9337
# Epoch 90/100
# 117/117 [==============================] - 88s 755ms/step - loss: 0.0551 - accuracy: 0.9852 - val_loss: 0.1441 - val_accuracy: 0.9520
# Epoch 91/100
# 117/117 [==============================] - 87s 744ms/step - loss: 0.0606 - accuracy: 0.9849 - val_loss: 0.1003 - val_accuracy: 0.9672
# Epoch 92/100
# 117/117 [==============================] - 89s 765ms/step - loss: 0.0640 - accuracy: 0.9818 - val_loss: 0.1279 - val_accuracy: 0.9616
# Epoch 93/100
# 117/117 [==============================] - 89s 760ms/step - loss: 0.0656 - accuracy: 0.9801 - val_loss: 0.0674 - val_accuracy: 0.9776
# Epoch 94/100
# 117/117 [==============================] - 88s 756ms/step - loss: 0.0607 - accuracy: 0.9822 - val_loss: 0.6062 - val_accuracy: 0.8122
# Epoch 95/100
# 117/117 [==============================] - 90s 770ms/step - loss: 0.0462 - accuracy: 0.9866 - val_loss: 0.1953 - val_accuracy: 0.9440
# Epoch 96/100
# 117/117 [==============================] - 88s 753ms/step - loss: 0.0699 - accuracy: 0.9798 - val_loss: 0.5497 - val_accuracy: 0.8225
# Epoch 97/100
# 117/117 [==============================] - 91s 778ms/step - loss: 0.0678 - accuracy: 0.9794 - val_loss: 0.2015 - val_accuracy: 0.9361
# Epoch 98/100
# 117/117 [==============================] - 90s 766ms/step - loss: 0.0748 - accuracy: 0.9798 - val_loss: 0.2754 - val_accuracy: 0.9129
# Epoch 99/100
# 117/117 [==============================] - 88s 752ms/step - loss: 0.0496 - accuracy: 0.9856 - val_loss: 0.3838 - val_accuracy: 0.8665
# Epoch 100/100
# 117/117 [==============================] - 88s 754ms/step - loss: 0.0495 - accuracy: 0.9870 - val_loss: 0.1098 - val_accuracy: 0.9640

# %%
#훈련 및 검증 정확도 시각화
#학습 정확성 값과 검증 정확성 값
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# 학습 손실 값과 검증 손실 값
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'validation'], loc='upper left')
plt.show()

# %%
#model test
loss, accuracy = model.evaluate_generator(test_generator)
print('test loss: ', loss, '\ntest accuracy: ', accuracy)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# test loss:  0.12792405486106873
# test accuracy:  0.9598085880279541

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpcqjex4ut/assets
